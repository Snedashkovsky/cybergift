# %% [markdown]
# ## Extraordinary Hackers and Masters of the Great Web. Gas Analysis

# %%
from math import log10

from config import PROJECT_ID, GAS_ANALYSIS_DATASET_NAME, INITIAL_TS, SNAPSHOT_TS, \
    GAS_ANALYSIS_DISTRIBUTION_TABLE_NAME, GAS_SPEND_BY_CONTRACT_TABLE_NAME, GAS_SPEND_BY_CREATOR_TABLE_NAME
from src.utils_bigquery import drop_table, create_table, get_df
from src.utils_charts import grade_boundaries_analysis

DROP_TABLES = True
CREATE_TABLES = True

# %%
spending_fee_by_contract_creator_initial_boundary = 0
spending_fee_by_contract_creator_by_factory_initial_boundary = 0
spending_fee_by_factory_creator = [0, 0, 10]

# %% [markdown]
# ### Create Table with Spending Gas by Contracts

# %%
query_1 = f'''
    WITH gas_spend AS (
        SELECT
            from_address,
            to_address,
            sum(cast(receipt_gas_used as numeric) * cast(gas_price as numeric))/1e18 as fee
        FROM `bigquery-public-data.crypto_ethereum.transactions`
        WHERE block_timestamp >= '{INITIAL_TS}'
          AND block_timestamp <= '{SNAPSHOT_TS}'
        GROUP BY from_address, to_address
        ORDER BY fee DESC
    ),
    traces_with_contracts_creation AS (
        SELECT
            transaction_hash,
            from_address,
            to_address
        FROM `bigquery-public-data.crypto_ethereum.traces`
        WHERE block_timestamp >= '{INITIAL_TS}'
          AND block_timestamp <= '{SNAPSHOT_TS}'
          AND trace_type ='create'
          AND status = 1),
    tx_sender_and_hash AS (
        SELECT
            from_address,
            `hash` as transaction_hash
        FROM `bigquery-public-data.crypto_ethereum.transactions`
        WHERE block_timestamp >= '{INITIAL_TS}'
          AND block_timestamp <= '{SNAPSHOT_TS}')
    SELECT
        contract_address,
        factory_address,
        creator_address,
        sum(fee) as fee
    FROM (
        SELECT
            contracts_creation.to_address as contract_address,
            if(contracts_creation.from_address = tx_sender.from_address, null, contracts_creation.from_address)  as factory_address,
            tx_sender.from_address as creator_address,
            gas.fee as fee
        FROM gas_spend as gas
        INNER JOIN traces_with_contracts_creation as contracts_creation
            ON gas.to_address = contracts_creation.to_address
        LEFT JOIN tx_sender_and_hash as tx_sender
            ON contracts_creation.transaction_hash = tx_sender.transaction_hash
               AND gas.from_address != tx_sender.from_address)
    GROUP BY contract_address, factory_address, creator_address
'''

if DROP_TABLES:
    drop_table(table_name=GAS_SPEND_BY_CONTRACT_TABLE_NAME,
               dataset_name=GAS_ANALYSIS_DATASET_NAME)
if CREATE_TABLES:
    create_table(query=query_1,
                 table_name=GAS_SPEND_BY_CONTRACT_TABLE_NAME,
                 dataset_name=GAS_ANALYSIS_DATASET_NAME)
# Out:
# Table gas_analysis:gas_spend_by_contract has been deleted.
# Table gas_analysis:gas_spend_by_contract has been created and filled 5,752,538 rows.

# %% [markdown]
# ### Create Table with Distribution by Contract and Factory Creators

# %%
query_2 = f'''
    WITH fee_by_factory AS (
        SELECT
            factory_address,
            sum(fee) as sum_fee
        FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CONTRACT_TABLE_NAME}`
        WHERE factory_address is not null
          AND creator_address is not null
        GROUP BY factory_address
        ),
    factory_creators AS (
        SELECT
            contract_address as factory_address,
            creator_address as factory_creator
        FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CONTRACT_TABLE_NAME}`
        WHERE contract_address IN (
            SELECT DISTINCT factory_address
            FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CONTRACT_TABLE_NAME}`
            )
          AND creator_address is not null
        ),
    contract_creators AS (
        SELECT
            address,
            segment,
            sum(fee) as sum_fee
        FROM (
            SELECT
                creator_address as address,
                if(factory_address is null, 'Contract Creator', 'Contract Creator by Factory') as segment,
                fee
            FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CONTRACT_TABLE_NAME}`
            WHERE creator_address is not null
            )
        GROUP BY address, segment)
    SELECT
        'Factory Creator' as segment,
        factory_creator as address,
        sum_fee
    FROM (
        SELECT
            factory_creator,
            sum(sum_fee) as sum_fee
        FROM fee_by_factory as ff
        LEFT JOIN factory_creators as fc ON ff.factory_address = fc.factory_address
        GROUP BY factory_creator)
    WHERE factory_creator is not null

    UNION ALL

    SELECT
        segment,
        address,
        sum_fee
    FROM contract_creators

    ORDER BY sum_fee DESC;
'''

if DROP_TABLES:
    drop_table(table_name=GAS_SPEND_BY_CREATOR_TABLE_NAME,
               dataset_name=GAS_ANALYSIS_DATASET_NAME)
if CREATE_TABLES:
    create_table(query=query_2,
                 table_name=GAS_SPEND_BY_CREATOR_TABLE_NAME,
                 dataset_name=GAS_ANALYSIS_DATASET_NAME)
# Out:
# 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/cosmic-keep-223223/datasets/gas_analysis/tables/gas_spend_by_creator?prettyPrint=false: Not found: Table cosmic-keep-223223:gas_analysis.gas_spend_by_creator
# Table gas_analysis:gas_spend_by_creator has not been deleted.
# Table gas_analysis:gas_spend_by_creator has been created and filled 674,451 rows.

# %% [markdown]
# ### Analysis of Grade Boundaries. Extraordinary Hackers. Fee Spending to Created Contracts by Contract Creators

# %%
query_4 = f'''
    SELECT
        ROUND(sum_fee - 0.004999, 2) + 0.004999 AS fee_class,
        count(address) as number_of_creators
    FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CREATOR_TABLE_NAME}`
    WHERE segment = 'Contract Creator'
      AND sum_fee > 0
    GROUP BY fee_class
    ORDER BY fee_class;
'''
fee_spending_hackers_distribution_df = get_df(query_4)

# %%
spending_fee_by_contract_creator = \
    grade_boundaries_analysis(
        distribution_df=fee_spending_hackers_distribution_df,
        value_column = 'fee_class',
        address_column='number_of_creators',
        address_chart_label='Number of contract creator addresses',
        value_chart_label = 'Fee spending to created contracts by contract creators, log10',
        value_name = 'Fee spending to created contracts',
        value_transform_func=lambda x: log10(x) if x > 0 else -2.5,
        chart_title = 'Distribution of Fee Spending to Created Contracts',
        max_show_value = 500,
        initial_boundary=spending_fee_by_contract_creator_initial_boundary,
        level_line_shift=0)
# Out:
# Suggestion of Rules:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Grade</th>
#       <th>Rule</th>
#       <th>Addresses</th>
#       <th>Percentage of Addresses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0 &lt; Fee spending to created contracts &lt;= 4.0</td>
#       <td>98512</td>
#       <td>88.9</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.0 &lt; Fee spending to created contracts &lt;= 254.0</td>
#       <td>11243</td>
#       <td>10.1</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>254.0 &lt; Fee spending to created contracts</td>
#       <td>1109</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Distribution Rules. Extraordinary Hackers
#
# <table style="text-align: center">
#     <thead>
#         <tr>
#             <th rowspan=2> Fee spending to created contracts<sup>1</sup>, ETH </th>
#             <th colspan=3>Grade</th>
#         </tr>
#         <tr>
#             <th>1</th>
#             <th>2</th>
#             <th>3</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="text-align: left"> - by contract creators<sup>2</sup> </td>
#             <td> > 0 ETH </td>
#             <td> > 4 ETH </td>
#             <td> > 254 ETH </td>
#         </tr>
#         <tr>
#             <td style="text-align: left"> - by factory creators<sup>3</sup> </td>
#             <td> - </td>
#             <td> > 0 ETH </td>
#             <td> > 10 ETH </td>
#         </tr>
#     </tbody>
# </table>
# <i>
# <sup>1</sup>  excluding fee from a contract creator address<br>
# <sup>2</sup>  excluding contracts created by factories<br>
# <sup>3</sup>  excluding factories that only created contracts when called from the creator of that factory
# </i>
# <br><br>

# %% [markdown]
# ### Analysis of Grade Boundaries. Masters of the Great Web. Fee Spending to Created Contracts

# %%
query_5 = f'''
    SELECT
        ROUND(sum_fee - 0.000499, 3) + 0.000499 AS fee_class,
        count(address) as number_of_creators
    FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CREATOR_TABLE_NAME}`
    WHERE segment = 'Contract Creator by Factory'
      AND sum_fee > {spending_fee_by_contract_creator_by_factory_initial_boundary}
    GROUP BY fee_class
    ORDER BY fee_class;
'''
fee_spending_masters_distribution_df = get_df(query_5)

# %%
spending_fee_by_contract_creator_by_factory = \
    grade_boundaries_analysis(
        distribution_df=fee_spending_masters_distribution_df,
        value_column='fee_class',
        address_column='number_of_creators',
        address_chart_label='Number of contract creator addresses',
        value_chart_label='Fee spending to created contracts by contract creators, log10',
        value_name='Fee spending to created contracts',
        value_transform_func=lambda x: log10(x) if x > 0 else -3.5,
        chart_title='Distribution of Fee Spending to Created Contracts',
        max_show_value=100,
        initial_boundary=spending_fee_by_contract_creator_by_factory_initial_boundary,
        level_line_shift=0,
        boundary_round=3)
# Out:
# Suggestion of Rules:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Grade</th>
#       <th>Rule</th>
#       <th>Addresses</th>
#       <th>Percentage of Addresses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0 &lt; Fee spending to created contracts &lt;= 0.004</td>
#       <td>485889</td>
#       <td>86.6</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.004 &lt; Fee spending to created contracts &lt;= 0.477</td>
#       <td>69682</td>
#       <td>12.4</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.477 &lt; Fee spending to created contracts</td>
#       <td>5617</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Distribution Rule. Masters of the Great Web
# Described in the [Masters of the Great Web](masters__erc721_analysis.ipynb) Jupyter notebook

# %% [markdown]
# ### Create Table with Distribution by Contract and Factory Creators

# %%
query_6 = f'''
    SELECT
        segment,
        address,
        sum_fee,
        CASE
            WHEN sum_fee > {spending_fee_by_factory_creator[2]} THEN 3
            WHEN sum_fee > {spending_fee_by_factory_creator[1]} THEN 2
            WHEN sum_fee > {spending_fee_by_factory_creator[0]} THEN 1
            ELSE null
        END
        AS grade
    FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CREATOR_TABLE_NAME}`
    WHERE segment = 'Factory Creator'

    UNION ALL

    SELECT
        segment,
        address,
        sum_fee,
        CASE
            WHEN (segment = 'Contract Creator' AND sum_fee > {spending_fee_by_contract_creator[2]}) OR
                 (segment = 'Contract Creator by Factory' AND sum_fee > {spending_fee_by_contract_creator_by_factory[2]}) THEN 3
            WHEN (segment = 'Contract Creator' AND sum_fee > {spending_fee_by_contract_creator[1]}) OR
                 (segment = 'Contract Creator by Factory' AND sum_fee > {spending_fee_by_contract_creator_by_factory[1]}) THEN 2
            WHEN (segment = 'Contract Creator' AND sum_fee > {spending_fee_by_contract_creator[0]}) OR
                 (segment = 'Contract Creator by Factory' AND sum_fee > {spending_fee_by_contract_creator_by_factory[0]}) THEN 1
            ELSE null
        END
        AS grade
    FROM `{PROJECT_ID}.{GAS_ANALYSIS_DATASET_NAME}.{GAS_SPEND_BY_CREATOR_TABLE_NAME}`
    WHERE segment in ('Contract Creator', 'Contract Creator by Factory')

    ORDER BY sum_fee DESC;
'''

if DROP_TABLES:
    drop_table(table_name=GAS_ANALYSIS_DISTRIBUTION_TABLE_NAME,
               dataset_name=GAS_ANALYSIS_DATASET_NAME)
if CREATE_TABLES:
    create_table(query=query_6,
                 table_name=GAS_ANALYSIS_DISTRIBUTION_TABLE_NAME,
                 dataset_name=GAS_ANALYSIS_DATASET_NAME)
# Out:
# Table gas_analysis:gas_analysis_distribution has been deleted.
# Table gas_analysis:gas_analysis_distribution has been created and filled 674,451 rows.
